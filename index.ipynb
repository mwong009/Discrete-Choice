# %%
import pandas as pd

pd.read_csv("dataset.txt",sep="\t")
# Out:
#      Postcode  age18_24  age25_34  age35_54  age_55  genderMale  employed  \
# 0        3014         0         0         0       1           0         1
# 1        1011         0         1         0       0           0         1
# 2        1012         0         0         1       0           1         0
# 3        2544         0         0         1       0           1         1
# 4        3523         0         1         0       0           1         1
# ..        ...       ...       ...       ...     ...         ...       ...
# 863      3581         0         1         0       0           0         0
# 864      2521         0         1         0       0           0         1
# 865      2584         0         1         0       0           0         1
# 866      3526         0         0         1       0           0         1
# 867      1012         0         1         0       0           0         1
#
#      selfEmployed  student  eduLower  ...  distWork  usedUber  hhSize  \
# ...
